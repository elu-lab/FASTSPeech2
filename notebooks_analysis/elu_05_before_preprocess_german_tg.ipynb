# %%
### tgt library: https://github.com/hbuschme/TextGridTools
### pyworld library: https://github.com/JeremyCCHsu/Python-Wrapper-for-World-Vocoder

# %% [markdown]
# ## import

# %%
import os
from pathlib import Path

import tgt
import numpy as np
import pandas as pd
import pyworld as pw
# import matplotlib.pyplot as plt

import librosa
import librosa.display
import IPython.display as ipd


from scipy.interpolate import interp1d
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm

# import audio as Audio
from stft import *

# %%
# !pwd
# Out:
# /home/heiscold/prac

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("train_mls_german.csv")
print(df.shape)
df.head()
# Out:
# (469942, 6)
#               file_id  speaker_id  chapter_id  utterance_id  \
# 0  10087_10388_000000       10087       10388             0
# 1  10087_10388_000001       10087       10388             1
# 2  10087_10388_000002       10087       10388             2
# 3  10087_10388_000003       10087       10388             3
# 4  10087_10388_000004       10087       10388             4
#
#                                             sentence  \
# 0  in deutschland protestierten friedrich wilhelm...
# 1  bald feuerwerk bald florett bald knotenstock u...
# 2  oder von stefan zweigs kultiviertem kosmopolit...
# 3  und nun rührt es sich überall in deutschland s...
# 4  ich weine weil man so allein ist man kann nich...
#
#                                           audio_path
# 0  /data/speech-data/mls/mls_german_opus/train/au...
# 1  /data/speech-data/mls/mls_german_opus/train/au...
# 2  /data/speech-data/mls/mls_german_opus/train/au...
# 3  /data/speech-data/mls/mls_german_opus/train/au...
# 4  /data/speech-data/mls/mls_german_opus/train/au...

# %%
idx = 11
audio_path = df.audio_path.values[idx]
sentence = df.sentence.values[idx]

print(f"Audio Path: {audio_path}")
print(f"SENTENCE: {sentence}")

sample_rate = 22050

audio, sr  = librosa.load(audio_path, sr= None)
## returned sr is 'orig_sr' of sound
print("ORIGINAL SAMPLE RATE: ", sr)
print("TARGET SAMPLE RATE", sample_rate)
print(f"SENTENCE: {sentence}")

## SAMPLE
audio = librosa.resample(audio, orig_sr= sr, target_sr= sample_rate )
ipd.display(ipd.Audio(audio, rate = sample_rate))
# Out:
# Audio Path: /data/speech-data/mls/mls_german_opus/train/audio/10087/10388/10087_10388_000011.opus
# SENTENCE: es ist unglücklicherweise noch alles realität wer damals als ludendorff hüben clemenceau drüben regierte sich zornig aufbäumte ist auch heute noch nicht offizier in der armee der vernünftigen leute sondern erst dabei ein paar korporale zusammenzutrommeln
# ORIGINAL SAMPLE RATE:  16000
# TARGET SAMPLE RATE 22050
# SENTENCE: es ist unglücklicherweise noch alles realität wer damals als ludendorff hüben clemenceau drüben regierte sich zornig aufbäumte ist auch heute noch nicht offizier in der armee der vernünftigen leute sondern erst dabei ein paar korporale zusammenzutrommeln
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#### STFT 실험 #####
# stft_fn = STFT(1024, 1024, 1024)
# s = audio / (np.max(audio) +1)
# out = stft_fn(torch.tensor(s.reshape(1, -1), dtype = torch.float))
# out

# %% [markdown]
# ## TextGrid Path: Sample(German)

# %%
lang = 'german'
tg_train_base_path = f'/data/speech-data/mls-align/mls_{lang}_opus/train/' 

lang, tg_train_base_path
# Out:
# ('german', '/data/speech-data/mls-align/mls_german_opus/train/')

# %%
all_train_tgt_paths = []
train_tg_path = [(str(p.stem), tg_train_base_path) for p in Path(tg_train_base_path).glob('*/*' + ".TextGrid")]
all_train_tgt_paths.extend(train_tg_path)
all_train_tgt_paths = sorted(all_train_tgt_paths)
len(all_train_tgt_paths)
# Out:
# 468823

# %%
# 469942 - 468823 # 1119
all_train_tgt_paths[0]
# Out:
# ('10087_10388_000000', '/data/speech-data/mls-align/mls_german_opus/train/')

# %%
df2 = pd.DataFrame()

df2['file_id'] = [s[0] for s in all_train_tgt_paths]
df2['tg_path'] = [s[1] + s[0].split("_")[0] + "/" + s[0] + ".TextGrid" for s in all_train_tgt_paths]
df2['speaker_id']= [tuple(file_id.split("_"))[0] for file_id in df2.file_id.to_list()]
df2['chapter_id']= [tuple(file_id.split("_"))[1] for file_id in df2.file_id.to_list()]
df2['utterance_id']= [str(tuple(file_id.split("_"))[2]) for file_id in df2.file_id.to_list()]

print(df2.shape)
df2.head()
# Out:
# (468823, 5)
#               file_id                                            tg_path  \
# 0  10087_10388_000000  /data/speech-data/mls-align/mls_german_opus/tr...
# 1  10087_10388_000001  /data/speech-data/mls-align/mls_german_opus/tr...
# 2  10087_10388_000002  /data/speech-data/mls-align/mls_german_opus/tr...
# 3  10087_10388_000003  /data/speech-data/mls-align/mls_german_opus/tr...
# 4  10087_10388_000004  /data/speech-data/mls-align/mls_german_opus/tr...
#
#   speaker_id chapter_id utterance_id
# 0      10087      10388       000000
# 1      10087      10388       000001
# 2      10087      10388       000002
# 3      10087      10388       000003
# 4      10087      10388       000004

# %%
df2.columns
# Out:
# Index(['file_id', 'tg_path', 'speaker_id', 'chapter_id', 'utterance_id'], dtype='object')

# %%
df2 = df2[['file_id', 'speaker_id', 'chapter_id', 'utterance_id', 'tg_path',]]
df2 = df2.sort_values(by=[df2.columns[1],df2.columns[2],df2.columns[3]],ascending=True)
df2 = df2.reset_index(drop = True) # index reset
print(df2.shape)
df2.head()
# Out:
# (468823, 5)
#               file_id speaker_id chapter_id utterance_id  \
# 0  10087_10388_000000      10087      10388       000000
# 1  10087_10388_000001      10087      10388       000001
# 2  10087_10388_000002      10087      10388       000002
# 3  10087_10388_000003      10087      10388       000003
# 4  10087_10388_000004      10087      10388       000004
#
#                                              tg_path
# 0  /data/speech-data/mls-align/mls_german_opus/tr...
# 1  /data/speech-data/mls-align/mls_german_opus/tr...
# 2  /data/speech-data/mls-align/mls_german_opus/tr...
# 3  /data/speech-data/mls-align/mls_german_opus/tr...
# 4  /data/speech-data/mls-align/mls_german_opus/tr...

# %%
df2.tg_path.values[0]
# Out:
# '/data/speech-data/mls-align/mls_german_opus/train/10087/10087_10388_000000.TextGrid'

# %%
## Save
df2.to_csv("temp_train_german_tg.csv", index=False)

# %% [markdown]
# ## Sample

# %%
idx = 0
audio_path = df.audio_path.values[idx]
sentence = df.sentence.values[idx]

print(f"Audio Path: {audio_path}")
print(f"SENTENCE: {sentence}")

sample_rate = 22050

audio, sr  = librosa.load(audio_path, sr= None)
## returned sr is 'orig_sr' of sound
print("ORIGINAL SAMPLE RATE: ", sr)
print("TARGET SAMPLE RATE", sample_rate)
print(f"SENTENCE: {sentence}")

## SAMPLE
audio = librosa.resample(audio, orig_sr= sr, target_sr= sample_rate )
ipd.display(ipd.Audio(audio, rate = sample_rate))
# Out:
# Audio Path: /data/speech-data/mls/mls_german_opus/train/audio/10087/10388/10087_10388_000000.opus
# SENTENCE: in deutschland protestierten friedrich wilhelm foerster der pädagoge und der arzt nicolai in frankreich erhebt seine stimme vom gebrüll der kriegspropaganda umtobt
# ORIGINAL SAMPLE RATE:  16000
# TARGET SAMPLE RATE 22050
# SENTENCE: in deutschland protestierten friedrich wilhelm foerster der pädagoge und der arzt nicolai in frankreich erhebt seine stimme vom gebrüll der kriegspropaganda umtobt
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_tg_path = df2.tg_path.values[idx]
sample_tg_path
# Out:
# '/data/speech-data/mls-align/mls_german_opus/train/10087/10087_10388_000000.TextGrid'

# %%
# Get alignments
textgrid = tgt.io.read_textgrid(sample_tg_path)
textgrid.get_tier_by_name("phones")
# Out:
# IntervalTier(start_time=0.0, end_time=11.55, name="phones", objects=[Interval(0.49, 0.57, "ɪ"), Interval(0.57, 0.62, "n"), Interval(0.62, 0.67, "d"), Interval(0.67, 0.79, "ɔʏ"), Interval(0.79, 0.92, "tʃ"), Interval(0.92, 0.96, "l"), Interval(0.96, 1.04, "a"), Interval(1.04, 1.07, "n"), Interval(1.07, 1.13, "t"), Interval(1.13, 1.17, "p"), Interval(1.17, 1.21, "ʁ"), Interval(1.21, 1.25, "ɔ"), Interval(1.25, 1.31, "tʰ"), Interval(1.31, 1.37, "ɛ"), Interval(1.37, 1.46, "s"), Interval(1.46, 1.51, "t"), Interval(1.51, 1.57, "iː"), Interval(1.57, 1.62, "ɐ"), Interval(1.62, 1.68, "tʰ"), Interval(1.68, 1.76, "n̩"), Interval(1.76, 1.84, "f"), Interval(1.84, 1.91, "ʁ"), Interval(1.91, 1.98, "iː"), Interval(1.98, 2.03, "d"), Interval(2.03, 2.09, "ʁ"), Interval(2.09, 2.15, "ɪ"), Interval(2.15, 2.22, "ç"), Interval(2.22, 2.26, "v"), Interval(2.26, 2.31, "ɪ"), Interval(2.31, 2.35, "l"), Interval(2.35, 2.39, "h"), Interval(2.39, 2.42, "ɛ"), Interval(2.42, 2.48, "l"), Interval(2.48, 2.53, "m"), Interval(2.53, 2.62, "f"), Interval(2.62, 2.66, "ɔ"), Interval(2.66, 2.74, "ɐ"), Interval(2.74, 2.86, "s"), Interval(2.86, 2.9, "t"), Interval(2.9, 3.09, "ɐ"), Interval(3.25, 3.3, "d"), Interval(3.3, 3.34, "eː"), Interval(3.34, 3.35, "ʁ"), Interval(3.35, 3.45, "pʰ"), Interval(3.45, 3.5, "ɛ"), Interval(3.5, 3.54, "d"), Interval(3.54, 3.6, "a"), Interval(3.6, 3.7, "ɡ"), Interval(3.7, 3.83, "oː"), Interval(3.83, 3.89, "ɡ"), Interval(3.89, 4.07, "ə"), Interval(4.36, 4.46, "ʊ"), Interval(4.46, 4.49, "n"), Interval(4.49, 4.54, "d"), Interval(4.54, 4.59, "eː"), Interval(4.59, 4.6, "ʁ"), Interval(4.6, 4.73, "aː"), Interval(4.73, 4.78, "ɐ"), Interval(4.78, 4.89, "ts"), Interval(4.89, 4.92, "t"), Interval(4.92, 4.96, "n"), Interval(4.96, 5.01, "ɪ"), Interval(5.01, 5.09, "kʰ"), Interval(5.09, 5.14, "ɔ"), Interval(5.14, 5.22, "l"), Interval(5.22, 5.47, "aj"), Interval(6.15, 6.22, "ɪ"), Interval(6.22, 6.28, "n"), Interval(6.28, 6.35, "f"), Interval(6.35, 6.4, "ʁ"), Interval(6.4, 6.48, "a"), Interval(6.48, 6.56, "ŋ"), Interval(6.56, 6.59, "k"), Interval(6.59, 6.67, "ʁ"), Interval(6.67, 6.78, "aj"), Interval(6.78, 6.87, "ç"), Interval(6.87, 6.95, "ɛ"), Interval(6.95, 6.98, "ɐ"), Interval(6.98, 7.05, "h"), Interval(7.05, 7.14, "eː"), Interval(7.14, 7.22, "p"), Interval(7.22, 7.25, "t"), Interval(7.25, 7.31, "z"), Interval(7.31, 7.37, "aj"), Interval(7.37, 7.43, "n"), Interval(7.43, 7.48, "ə"), Interval(7.48, 7.6, "ʃ"), Interval(7.6, 7.64, "t"), Interval(7.64, 7.69, "ɪ"), Interval(7.69, 7.77, "m"), Interval(7.77, 7.97, "ə"), Interval(8.25, 8.35, "f"), Interval(8.35, 8.41, "oː"), Interval(8.41, 8.5, "m"), Interval(8.5, 8.54, "ɡ"), Interval(8.54, 8.59, "ə"), Interval(8.59, 8.64, "b"), Interval(8.64, 8.7, "ʁ"), Interval(8.7, 8.76, "ʏ"), Interval(8.76, 8.88, "l"), Interval(8.88, 8.93, "d"), Interval(8.93, 9.0, "eː"), Interval(9.0, 9.01, "ʁ"), Interval(9.01, 9.09, "k"), Interval(9.09, 9.16, "ʁ"), Interval(9.16, 9.22, "iː"), Interval(9.22, 9.29, "k"), Interval(9.29, 9.38, "s"), Interval(9.38, 9.44, "p"), Interval(9.44, 9.48, "ʁ"), Interval(9.48, 9.51, "ɔ"), Interval(9.51, 9.58, "pʰ"), Interval(9.58, 9.65, "a"), Interval(9.65, 9.72, "ɡ"), Interval(9.72, 9.79, "a"), Interval(9.79, 9.86, "n"), Interval(9.86, 9.91, "d"), Interval(9.91, 9.97, "a"), Interval(9.97, 10.03, "ʊ"), Interval(10.03, 10.13, "m"), Interval(10.13, 10.22, "tʰ"), Interval(10.22, 10.36, "oː"), Interval(10.36, 10.43, "p"), Interval(10.43, 10.58, "t")])
